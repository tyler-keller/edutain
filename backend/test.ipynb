# %%
from ebooklib import epub

book = epub.read_epub('input/book.epub')

for item in book.get_items():
    print(item.get_name())
# Out:
# 9780063286368_toc.ncx
# styles/9780063286368_template.css
# text/nav.xhtml
# text/9780063286368_Cover.xhtml
# text/9780063286368_Titlepage.xhtml
# text/9780063286368_Dedication.xhtml
# text/9780063286368_Epigraph.xhtml
# text/9780063286368_Contents.xhtml
# text/9780063286368_Frontmatter_1.xhtml
# text/9780063286368_Frontmatter_2.xhtml
# text/9780063286368_Frontmatter_3.xhtml
# text/9780063286368_Introduction.xhtml
# text/9780063286368_Chapter_1.xhtml
# text/9780063286368_Part_1.xhtml
# text/9780063286368_Chapter_2.xhtml
# text/9780063286368_Chapter_3.xhtml
# text/9780063286368_Chapter_4.xhtml
# text/9780063286368_Chapter_4a.xhtml
# text/9780063286368_Part_2.xhtml
# text/9780063286368_Chapter_5.xhtml
# text/9780063286368_Chapter_6.xhtml
# text/9780063286368_Chapter_7.xhtml
# text/9780063286368_Chapter_8.xhtml
# text/9780063286368_Chapter_9.xhtml
# text/9780063286368_Chapter_9a.xhtml
# text/9780063286368_Part_3.xhtml
# text/9780063286368_Chapter_10.xhtml
# ...
